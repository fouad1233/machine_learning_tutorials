# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('data/spam.csv' , encoding = 'latin-1')

# %%
print(dataset)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
labels , messages = dataset['v1'].values , dataset['v2'].values

# %%
print(labels)
print(messages)
# Out:
# ['ham' 'ham' 'spam' ... 'ham' 'ham' 'ham']
# ['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'
#  'Ok lar... Joking wif u oni...'
#  "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"
#  ... 'Pity, * was in mood for that. So...any other suggestions?'
#  "The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free"
#  'Rofl. Its true to its name']

# %%
word_set = set()
for message in messages:
    for word in message.split():
        word_set.add(word)
        
print(word_set)
# Out:
# {'anybody.', '\\Hey', 'else....', '1.50p', 'Wondering', 'welp', 'on?', 'laugh', 'ones,', 'DRAW', 'vs.', 'THNQ', 'action', 'NO-440', 'onwards...', 'you!', 'of', 'www.win-82050.co.uk', 'NR31', 'alrite.', 'Yep', 'abnormally.', 'pap', 'again:)', 'spoon', 'management', 'browsin', 'holiday', 'smarter', 'rights', 'everywhere...', 'Cut', 'Jsut', 'W111WX', 'lot..i', 'sleeping,', 'MITE', 'ears', 'topped', 'Fills', 'disclose', 'bhayandar', 'sucks.', 'Morning.', 'chikku..k,', 'anyway,', 'STAR', 'Care..:-)', 'lk', 'nokias', 'DRUNK!', 'Chef', 'www.clubmoby.com', '&amp;', 'accomodations.', 'boggy', 'YRS', 'peoples', 'Thank.', 'Wn', 'Dizzee', 'angry', 'moment', 'Both', '1hr', 'breeze...', 'clock.', 'sub,', 'fucks', 'trained', 'person', 'bac', '26/10/04', 'shrek', 'LST', 'Ard', 'mind?', 'sea', '\\Boost', 'Row/W1JHL', 'opened', '\\Our', 'worry', 'tough,', '09701213186', 'time..:-)', 'lighters', "'That", 'placement', 'instructions.', 'carry', 'etc.?', 'direct', 'details', '?1,000', 'situations:', 'flash.', 'Chk', 'facilities', 'outstanding', 'now!"', 'Don\x89Û÷t', 'shipped.', 'grandma', 'going?', 'AVE', 'sup', 'ar?', "dealer's", 'tmr', 'vikky..', '85069', 'tho!', 'nothing.', 'signal.', '3optical', 'Out', ':-xx', 'SOIREE', '09061213237', 'Chloe,', 'jelly', 'jules', "That'll", 'LIVE.', 'timing', 'bare', '6-Ramaduth', 'come:)i', 'meaningless', 'Guild.', 'wet.', 'one,', 'office:)whats', 'King', '08715203677', 'way!', 'size', 'forward', 'shore', 'ivatte', 'week?', 'Pansy!', 'snowball', 'greatest', 'naughty', 'BABY', 'talent.', 'Sat', '(25p),', 'milk', 'PT2', 'Trav,', 'requests', 'Traffic', 'transport', 'steak', 'weather', 'ever,', 'messages..im', 'THATMUM', 'done.', 'mine.', 'finishing', 'covers', 'Well.', 'ARE', 'inch', 'ass*', '2MORO', 'about.', 'think???', 'princess.', 'fond', 'parantella', 'One', '\\Aww', 'evo.', 'going,', 'evey', 'Valid12hrs', 'problems.', 'name?', 'bathing', 'MUMS', 'laugh.', 'listn', 'Got', '08706091795.', 'case...', 'std', 'funs', 'pages', 'fiting', 'Reference', 'half', 'Fuck,', 'test:-).', 'Gossip,', 'boring.', '\\Keep', 'grateful', 'commercial', 'wamma', '.dont', 'expensive.', 'World*', 'this...', 'AGE', 'trusting', 'Each', 'shopping.', 'Jones!', 'de:-)', 'bandages', 'wow', 'talk?', 'Christmas!Merry', 'in.', 'Love:', 'sack', 'åÒHarry', 'hanging', 'Oic', 'Sun', 'Evn', 'Muz', 'evening', 'disconnected', 'loving,', '(to', 'route', 'reply', 'something...', 'senrd-dnot', 'calls', 'India.', 'u,', 'damn', 'law;', 'Buzz', 'virgin', 'stink!', 'complaining', 'ST', 'charming', 'toshiba...', 'jokes...', '7ish?', "didn't.", 'pehle', 'Boys', 'SP:RWM', 'buffet', 'It...!..!!', 'Box334', 'yi', 'Driver', 'fast', 'net', 'Mmmm....', 'anna', 'å£1.50pm', 'LONGER', 'effect', 'dear', '48922', 'Joke', 'THAT', 'world....gnun', 'Jokin', '9t:)', 'pending', "that's", 'Great.', 'time.you', "tt's", 'john', 'dubsack', 'questions', 'subscribe', 'OUTL8R', 'upset', '\\X\\"', 'vilikkam....t', 'analysis', 'Fffff.', 'darren', 'Yet,', 'fuckin', 'stranger', 'fetching', 'groovy.', 'skip', 'suits', 'je', 'Sweetest', 'self', 'Mmmmm', 'plane..', 'working!', 'Solve', 'pierre', 'potato', 'SP', 'IåÕm', 'BABE!', 'yelling', 'secret', '08452810071', 'warning', 'june..', 'journey', 'dock,', 'Adult', 'farting', 'lo', 'gave', 'pa', 'forå£38', '(nat', 'nothing', 'inpersonation', 'plans?', 'IT.(NOW', 'lost.', 'chat...', 'superb', 'pmt', 'rocks', 'down:)', 'feelin', 'telugu', 'Sez,', 'at', 'types', 'me..', 'cam', 'matters', 'provided', 'å£5', 'enemy..', 'installing.', 'Indians.', 'naked', '2moro', 'tv..he', 'food', 'copied', 'update', '\\Ur', 'individual', 'evrydy', 'Helloooo...', 'inperialmusic', 'bank', 'adore', '255.', 'Allo!', 'photo', 'REALY', 'Landline.', 'footie', 'GOODMORNING"', 'VU', 'God,', 'Drop,', 'busy...', '08715205273', 'loosing', 'award', 'use?', 'MP3', 'å£1/minMobsmoreLKPOBOX177HP51FL', 'Taka', 'stocked', 'rush,', 'Oops.', 'south', 'srsly', 'eyes...', 'appointment', 'now!still', 'prabha', "shit's", 'bck.', 'Frog-AXEL', 'U,', 'pounded', '2004', 'request', 'def', ' ...

# %%
word_list = list(word_set)
word_list = np.array(word_list)
print(len(word_list))
# Out:
# 15585

# %%
# make a dictionary of words and their spam counts and ham counts
word_dict = {}
for word in word_list:
    word_dict[word] = (0,0)

for i in range(len(messages)):
    for word in messages[i].split():
        word_dict[word] = (word_dict[word][0] + (labels[i] == 'spam'), word_dict[word][1] + (labels[i] == 'ham'))
print(word_dict)
# Out:
# {'anybody.': (0, 2), '\\Hey': (0, 2), 'else....': (1, 0), '1.50p': (1, 0), 'Wondering': (0, 1), 'welp': (0, 1), 'on?': (0, 2), 'laugh': (0, 5), 'ones,': (0, 1), 'DRAW': (3, 0), 'vs.': (0, 1), 'THNQ': (1, 0), 'action': (1, 0), 'NO-440': (2, 0), 'onwards...': (0, 1), 'you!': (12, 18), 'of': (93, 498), 'www.win-82050.co.uk': (2, 0), 'NR31': (1, 0), 'alrite.': (0, 1), 'Yep': (0, 4), 'abnormally.': (0, 1), 'pap': (0, 2), 'again:)': (0, 1), 'spoon': (0, 1), 'management': (0, 3), 'browsin': (0, 1), 'holiday': (10, 8), 'smarter': (0, 1), 'rights': (0, 2), 'everywhere...': (0, 1), 'Cut': (0, 1), 'Jsut': (0, 2), 'W111WX': (4, 0), 'lot..i': (0, 1), 'sleeping,': (0, 3), 'MITE': (0, 1), 'ears': (0, 1), 'topped': (1, 
 1), 'going,': (0, 1), 'evey': (0, 1), 'Valid12hrs': (3, 0), 'problems.': (0, 1), 'name?': (0, 1), 'bathing': (0, 3), 'MUMS': (0, 1), 'laugh.': (0, 1), 'listn': (0, 1), 'Got': (2, 22), '08706091795.': (1, 0), 'case...': (0, 1), 'std': (2, 0), 'funs': (0, 1), 'pages': (0, 2), 'fiting': (0, 1), 'Reference': (1, 0), 'half': (5, 25), 'Fuck,': (0, 2), 'test:-).': (0, 1), 'Gossip,': (1, 0), 'boring.': (0, 1), '\\Keep': (0, 1), 'grateful': (0, 1), 'commercial': (0, 1), 'wamma': (1, 0), '.dont': (0, 1), 'expensive.': (0, 3), 'World*': (0, 3), 'this...': (0, 1), 'AGE': (6, 0), 'trusting': (0, 1), 'Each': (0, 3), 'shopping.': (0, 2), 'Jones!': (0, 1), 'de:-)': (0, 1), 'bandages': (0, 1), 'wow': (1, 1), 'talk?': (0, 1), 'Christmas!Merry': (0,  ...

# %%
#write the dictionary to an excel file, write words and their spam and ham counts, total spam message number and total ham message number
df = pd.DataFrame(word_dict)
df = df.T
df.columns = ['spam_count', 'ham_count']
df['total_spam'] = len(labels[labels == 'spam'])
df['total_ham'] = len(labels[labels == 'ham'])
df.to_excel('data/word_spam_ham_counts.xlsx')

# %%
#read the words and their spam and ham counts, total spam message number and total ham message number from the excel file
df = pd.read_excel('data/word_spam_ham_counts.xlsx')
words = df['Unnamed: 0'].values
spam_counts = df['spam_count'].values
ham_counts = df['ham_count'].values
total_spam = df['total_spam'].values[0]
total_ham = df['total_ham'].values[0]

# %%
# calculate the probability of a word being spam or ham
p_spam_word = spam_counts / total_spam
p_ham_word = ham_counts / total_ham
p_spam = total_spam / (total_spam + total_ham)
p_ham = total_ham / (total_spam + total_ham)

# %%
print(p_spam_word)
print(p_ham_word)
print(p_spam)
print(p_ham)
# Out:
# [0.         0.         0.00133869 ... 0.         0.         0.        ]
# [0.00041451 0.00041451 0.         ... 0.00062176 0.00020725 0.00020725]
# 0.13406317300789664
# 0.8659368269921034

# %%
def predict_spam_or_ham(words, message , p_spam_word , p_ham_word, p_spam = 0.5, p_ham = 0.5):
    p_spam_message = p_spam
    p_ham_message = p_ham
    for word in message.split():
        if word in words:
            p_spam_message *=  p_spam_word[words == word][0]
            p_ham_message *=  p_ham_word[words == word][0]
    return p_spam_message, p_ham_message

# %%
print(predict_spam_or_ham(words, 'I am going to school', p_spam_word, p_ham_word, p_spam, p_ham))
# Out:
# (0.0, 3.791373475744043e-07)

# %%
def test_spam_or_ham_model(words, messages, labels, p_spam_word, p_ham_word, p_spam = 0.5, p_ham = 0.5):
    # calculate true positive, true negative, false positive and false negative
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    for i in range(len(messages)):
        p_spam_message, p_ham_message = predict_spam_or_ham(words, messages[i], p_spam_word, p_ham_word, p_spam, p_ham)
        if p_spam_message > p_ham_message:
            if labels[i] == 'spam':
                tp += 1
            else:
                fp += 1
        else:
            if labels[i] == 'ham':
                tn += 1
            else:
                fn += 1
    return tp, tn, fp, fn

# %%
#Test the model
tp, tn, fp,fn = test_spam_or_ham_model(words, messages, labels, p_spam_word, p_ham_word, p_spam, p_ham)
accuracy = (tp + tn) / (tp + tn + fp + fn)
precision = tp / (tp + fp)
recall = tp / (tp + fn)
f1 = 2 * precision * recall / (precision + recall)
print(accuracy, precision, recall, f1)
# Out:
# 0.9989231873653984 0.9920318725099602 1.0 0.996
